# %% [markdown]
# L’examen est sur machine.
# Vous avez droit à vos TP, notes, cours et croissants (Tout, sauf faire l’examen à plusieurs et toute IA).
#
# A la fin de l’examen, envoyez le fichier (*Télécharger -> Télécharger le fichier ipynb*) à clement.truillet@irit.fr et vous pouvez partir !
#
# Pour le projet, vous avez bien sûr le droit de poser des questions, que ce soit par mail ou en présentiel (on peut convenir d’un créneau et un endroit :))
#
# Bonne chance !

# %% [markdown]
# **Pour supprimer l'IA**
# Allez dans *Outils*
# -> Décochez "*A autorisé l'utilisation des fonctionnalitées d'IA générative*"
# -> Cochez "*Masquer les fonctionnalitées d'IA génératives*"

# %% [markdown]
# L'ensemble des TP et corrections sont ici : [short.ctruillet.eu/TPGCGEO](https://short.ctruillet.eu/TPGCGEO)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Exercice 1 - Abonnement (6 points)
#
# Une personne souhaite s'abonner à un site de streaming à partir du 1er janvier 2025. Elle a le choix entre deux formules.
#
# - **Formule 1** : la personne paye directement 180 € son abonnement par an.
# - **Formule 2** : la personne paye 8.99 € par mois la premiere année et accepte une augmentation mensuelle de 3% de son abonnement à partir d'un an.
#
# Ecrivez un programme qui permet de connaître le gain à l’issue de 5 ans d'abonnement et de déterminer quel est la meilleure formule.
#
# > **Nota :** Les valeurs décimales seront arrondies, si nécessaire, au centime près
# >

# %%
# Votre code ici !

# %% [markdown]
# # Exercice 2 - Calcul et affichage (8 points)
# On cherche à calculer :
#
# $$
# 7\displaystyle\sum_{n=0}^{+\inf}\frac{(-1)^n}{4n+2}
# $$
#
# Et
#
# $$
# \sqrt{3\sum_{n=1}^{+\inf}\frac{2^n}{e^n}}
# $$
#
# 1. Ecrire une fonction f(n) et g(n) permettant de calculer ces sommes (3 + 3 pts)
# 2. Ecrire un script qui permette d’afficher dans deux figures d’une même fenêtre (*subplot*) en rouge et bleu le résultat des 500 premiers termes pour chacune des fonctions centrées sur les mêmes valeurs (entre 2.6 et 3.0 en y). (2 pts)

# %%
# Votre code ici !

# %% [markdown]
# # Exercice 3 - Graphisme (6 points)
#
# Créer une fonction $[x,y,z] = barrel(theta, phi)$ qui représente un tonneau et est définie de la manière suivante :
#
# $$\begin{equation}
# x = ({R} + {r}\cos{ϕ})\sin{θ} \\
# y = ({R} + {r}\cos{ϕ})\cos{θ}\\
# z = {r}\sin{ϕ}
# \end{equation}
# $$
#
# Pour $θ$ variant de $0$ à $2\pi+0.1$ par pas de $0.1$ et $ϕ$ variant de $0$ à $2\pi+0.1$ avec le même pas.
#
# On prendra
#
# $$\begin{equation}
# {R} = 1 \\
# {r} = 0.3
# \end{equation}
# $$
#
# Représentez graphiquement la fonction **barrel(theta, phi)** par l’intermédiaire d’un script.

# %%
# Votre code ici !

# %% [markdown]
# A l’issue du contrôle continu, vous enverrez vos fichiers à
# [philippe.truillet@irit.fr](mailto:philippe.truillet@irit.fr) ou à clement.truillet@irit.fr avec le sujet suivant: [CC1] – Nom Prénom
